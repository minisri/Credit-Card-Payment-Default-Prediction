# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv(r'C:\Users\ananyya srivastava\Downloads\trainj.csv')

# %%
test=pd.read_csv(r'C:\Users\ananyya srivastava\Downloads\testj.csv')

# %%
sample=pd.read_csv(r'C:\Users\ananyya srivastava\Downloads\samplej.csv')

# %%
train.head()
# Out:
#       ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0  25150     360000    2          2         2   25     -1     -1     -1
# 1  13470     240000    2          1         2   46      2      2     -2
# 2   3092     320000    2          2         1   41      0      0      0
# 3  13973      50000    2          2         2   24     -1     -1     -2
# 4  10567      80000    1          3         1   52     -1      0      0
#
#    PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -1  ...       3435       8870       2020     12590      3479      3446
# 1     -1  ...       2240       1681       2267         0         0      2240
# 2      0  ...      35409      35036      35939      5000      2000      2000
# 3     -2  ...          0          0          0         0         0         0
# 4      0  ...      20561      21261      21457      1500      1500      1500
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# ...

# %%
test.head()
# Out:
#       ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0  10178      60000    2          2         1   30      0      0      0
# 1   5304     200000    2          1         2   29      0      0      0
# 2   5187     230000    1          1         2   39      0      0      0
# 3  14495     150000    1          1         2   40      0      0      0
# 4  20444     140000    1          2         2   27      0      0      0
#
#    PAY_4  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0      0  ...      38117      38874      38667      39544      1628      1618
# 1      0  ...      76593      93988      50292      10510      4160     14593
# 2      0  ...      20650          0          0          0      2500      2000
# 3      0  ...     145978     139791     142745     146872      5800      5245
# 4      0  ...      76230      77954      78953      81848     10000     10000
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# ...

# %%
train.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default_payment_next_month    0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# ID           0
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_0        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# dtype: int64

# %%
sample.isnull().sum()
# Out:
# ID                            0
# default_payment_next_month    0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21000 entries, 0 to 20999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          21000 non-null  int64
#  1   LIMIT_BAL                   21000 non-null  int64
#  2   SEX                         21000 non-null  int64
#  3   EDUCATION                   21000 non-null  int64
#  4   MARRIAGE                    21000 non-null  int64
#  5   AGE                         21000 non-null  int64
#  6   PAY_0                       21000 non-null  int64
#  7   PAY_2                       21000 non-null  int64
#  8   PAY_3                       21000 non-null  int64
#  9   PAY_4                       21000 non-null  int64
#  10  PAY_5                       21000 non-null  int64
#  11  PAY_6                       21000 non-null  int64
#  12  BILL_AMT1                   21000 non-null  int64
# ...

# %%
train.describe()
# Out:
#                  ID      LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  21000.000000   21000.000000  21000.000000  21000.000000  21000.000000
# mean   14949.183667  167214.746667      1.607571      1.854190      1.551714
# std     8632.775153  128965.188482      0.488303      0.791628      0.521176
# min        1.000000   10000.000000      1.000000      0.000000      0.000000
# 25%     7508.750000   50000.000000      1.000000      1.000000      1.000000
# 50%    14939.500000  140000.000000      2.000000      2.000000      2.000000
# 75%    22386.750000  240000.000000      2.000000      2.000000      2.000000
# max    29998.000000  800000.000000      2.000000      6.000000      3.000000
#
#                 AGE        PAY_0         PAY_2         PAY_3        PAY_4  \
# count  21000.000000  21000.00000  21000.000000  21000.000000  21000.00000
# mean      35.461619     -0.01119     -0.127238     -0.164857     -0.21819
# ...

# %%
train.shape
# Out:
# (21000, 25)

# %%
test.shape
# Out:
# (9000, 24)

# %%
sample.shape
# Out:
# (9000, 2)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 24 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         9000 non-null   int64
#  1   LIMIT_BAL  9000 non-null   int64
#  2   SEX        9000 non-null   int64
#  3   EDUCATION  9000 non-null   int64
#  4   MARRIAGE   9000 non-null   int64
#  5   AGE        9000 non-null   int64
#  6   PAY_0      9000 non-null   int64
#  7   PAY_2      9000 non-null   int64
#  8   PAY_3      9000 non-null   int64
#  9   PAY_4      9000 non-null   int64
#  10  PAY_5      9000 non-null   int64
#  11  PAY_6      9000 non-null   int64
#  12  BILL_AMT1  9000 non-null   int64
#  13  BILL_AMT2  9000 non-null   int64
#  14  BILL_AMT3  9000 non-null   int64
#  15  BILL_AMT4  9000 non-null   int64
#  16  BILL_AMT5  9000 non-null   int64
#  17  BILL_AMT6  9000 non-null   int64
#  18  PAY_AMT1   9000 non-null   int64
#  19  PAY_AMT2   9000 non-null   int64
# ...

# %%
train.dtypes
# Out:
# ID                            int64
# LIMIT_BAL                     int64
# SEX                           int64
# EDUCATION                     int64
# MARRIAGE                      int64
# AGE                           int64
# PAY_0                         int64
# PAY_2                         int64
# PAY_3                         int64
# PAY_4                         int64
# PAY_5                         int64
# PAY_6                         int64
# BILL_AMT1                     int64
# BILL_AMT2                     int64
# BILL_AMT3                     int64
# BILL_AMT4                     int64
# BILL_AMT5                     int64
# BILL_AMT6                     int64
# PAY_AMT1                      int64
# PAY_AMT2                      int64
# PAY_AMT3                      int64
# PAY_AMT4                      int64
# PAY_AMT5                      int64
# PAY_AMT6                      int64
# default_payment_next_month    int64
# dtype: object

# %%
test.dtypes
# Out:
# ID           int64
# LIMIT_BAL    int64
# SEX          int64
# EDUCATION    int64
# MARRIAGE     int64
# AGE          int64
# PAY_0        int64
# PAY_2        int64
# PAY_3        int64
# PAY_4        int64
# PAY_5        int64
# PAY_6        int64
# BILL_AMT1    int64
# BILL_AMT2    int64
# BILL_AMT3    int64
# BILL_AMT4    int64
# BILL_AMT5    int64
# BILL_AMT6    int64
# PAY_AMT1     int64
# PAY_AMT2     int64
# PAY_AMT3     int64
# PAY_AMT4     int64
# PAY_AMT5     int64
# PAY_AMT6     int64
# dtype: object

# %%
train.SEX.value_counts()
# Out:
# 2    12759
# 1     8241
# Name: SEX, dtype: int64

# %% [markdown]
# 2- female , 1- male

# %%
train.head()
# Out:
#       ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0  25150     360000    2          2         2   25     -1     -1     -1
# 1  13470     240000    2          1         2   46      2      2     -2
# 2   3092     320000    2          2         1   41      0      0      0
# 3  13973      50000    2          2         2   24     -1     -1     -2
# 4  10567      80000    1          3         1   52     -1      0      0
#
#    PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -1  ...       3435       8870       2020     12590      3479      3446
# 1     -1  ...       2240       1681       2267         0         0      2240
# 2      0  ...      35409      35036      35939      5000      2000      2000
# 3     -2  ...          0          0          0         0         0         0
# 4      0  ...      20561      21261      21457      1500      1500      1500
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# ...

# %%
train.MARRIAGE.value_counts()
# Out:
# 2    11184
# 1     9561
# 3      219
# 0       36
# Name: MARRIAGE, dtype: int64

# %% [markdown]
# ##### 1- married, 2- single , 3- divorced

# %%
train.EDUCATION.value_counts()
# Out:
# 2    9789
# 1    7415
# 3    3467
# 5     200
# 4      85
# 6      34
# 0      10
# Name: EDUCATION, dtype: int64

# %% [markdown]
# ##### 1- graduate school, 2 - university, 3- high school, 4-others, 5- unknown , unknown

# %%
sns.boxplot(x=train.AGE,data=train)

# %%
sns.distplot(train.AGE)
# Out:
# C:\Users\ananyya srivastava\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
train.default_payment_next_month.value_counts()
# Out:
# 0    16355
# 1     4645
# Name: default_payment_next_month, dtype: int64

# %% [markdown]
# 1- yes, 0-no

# %%
# plotting a donut chart for visualizing each of the recruitment channel's share

size = [16355, 4645]
colors = ['yellow', 'blue']
labels = "payment yes", "payment no"

my_circle = plt.Circle((0, 0), 0.7, color = 'white')

plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size, colors = colors, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Showing a Percentage who will do payment nbext month', fontsize = 30)
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.legend()
plt.show()

# %%
# scatter plot between education and payment next month

data = pd.crosstab(train['EDUCATION'], train['default_payment_next_month'])
data.div(data.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 9), color = ['blue', 'lightgreen'])

plt.title('Dependency of education and payment made next month', fontsize = 30)
plt.xlabel('education', fontsize = 15)
plt.legend()
plt.show()

# %%
# scatter plot between Gender and payment next month

data = pd.crosstab(train['SEX'], train['default_payment_next_month'])
data.div(data.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 9), color = ['magenta', 'lightgreen'])

plt.title('Dependency of Gender and payment made next month', fontsize = 30)
plt.xlabel('gender', fontsize = 15)
plt.legend()
plt.show()

# %%
sns.distplot(train.LIMIT_BAL)

# %%
sns.catplot(x='EDUCATION',y='LIMIT_BAL',kind='box',data=train)

# %%
sns.catplot(x='SEX',y='LIMIT_BAL',kind='box',hue='default_payment_next_month',data=train)

# %%
train.PAY_0.value_counts()
# Out:
#  0    10324
# -1     3937
#  1     2608
# -2     1923
#  2     1883
#  3      231
#  4       47
#  5       19
#  8       11
#  6        9
#  7        8
# Name: PAY_0, dtype: int64

# %%
# Repayment status in September, 2005 

plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(train['PAY_0'], color = 'yellow')
plt.title('Repayment status in September, 2005', fontsize = 30)
plt.xticks(rotation = 60)
plt.xlabel('payments made', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %% [markdown]
# -1=pay duly, 1=payment delay for one month, 2=payment delay for two months, ... 8=payment delay for eight months, 9=payment delay for nine months and above

# %%
train.PAY_2.value_counts()
# Out:
#  0    11043
# -1     4174
#  2     2776
# -2     2643
#  3      229
#  4       69
#  1       23
#  5       21
#  7       11
#  6       10
#  8        1
# Name: PAY_2, dtype: int64

# %%
# Repayment status in August, 2005 

plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(train['PAY_2'], color = 'lightblue')
plt.title('Repayment status in August, 2005', fontsize = 30)
plt.xticks(rotation = 60)
plt.xlabel('payments made', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
# Repayment status in JULY, 2005 

plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(train['PAY_3'], color = 'pink')
plt.title('Repayment status in JULY, 2005', fontsize = 30)
plt.xticks(rotation = 60)
plt.xlabel('payments made', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
# Repayment status in JUNE, 2005 

plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(train['PAY_4'], color = 'magenta')
plt.title('Repayment status in JUNE, 2005', fontsize = 30)
plt.xticks(rotation = 60)
plt.xlabel('payments made', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
# Repayment status in MAY, 2005 

plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(train['PAY_5'], color = 'red')
plt.title('Repayment status in MAY, 2005', fontsize = 30)
plt.xticks(rotation = 60)
plt.xlabel('payments made', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
# Repayment status in April, 2005 

plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(train['PAY_6'], color = 'orange')
plt.title('Repayment status in april, 2005', fontsize = 30)
plt.xticks(rotation = 60)
plt.xlabel('payments made', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(20,10)) 
sns.heatmap(data=train.corr(), annot=True, cmap='viridis')

# %%
sns.distplot(train.BILL_AMT1)
# Out:
# C:\Users\ananyya srivastava\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from sklearn.metrics import accuracy_score as acc
from sklearn.model_selection import train_test_split as tt

# %%
x = train.drop(['default_payment_next_month'], axis=1)
y = train[['default_payment_next_month']]
x_test = test
x_train, x_val, y_train, y_val = tt(x, y, test_size=0.20, random_state=42, shuffle=True)

# %%
# standard scaling

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_val  = sc.transform(x_val)
x_test = sc.transform(x_test)

# %%
from sklearn.ensemble import AdaBoostClassifier
abc =  AdaBoostClassifier()
abc.fit(x_train, y_train)

abc_pred = abc.predict(x_test)

print("Training Accuracy :", abc.score(x_train, y_train))
# Out:
# C:\Users\ananyya srivastava\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# C:\Users\ananyya srivastava\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training Accuracy : 0.8214285714285714

# %%
from xgboost.sklearn import XGBClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import average_precision_score

xgb = XGBClassifier()
xgb.fit(x_train, y_train)

xgb_pred = xgb.predict(x_test)

print("Training Accuracy :", xgb.score(x_train, y_train))
# Out:
# C:\Users\ananyya srivastava\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:95: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\ananyya srivastava\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:128: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training Accuracy : 0.8292261904761905
# C:\Users\ananyya srivastava\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ...

# %%
xgb_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
sample['ID']=test.ID
sample['default_payment_next_month']=xgb_pred

# %%
pd.DataFrame(sample, columns=['ID','default_payment_next_month']).to_csv('janta.csv',index=False)
